# %% [markdown]
# # 06 — Folium Interactive Map

# %%
import pandas as pd, folium
from folium.plugins import MarkerCluster
df=pd.read_csv("../data/cleaned_spacex_falcon9.csv")
m=folium.Map(location=[29,-95],zoom_start=4)
cluster=MarkerCluster().add_to(m)
for _,r in df.iterrows():
    folium.CircleMarker([r.Latitude,r.Longitude],radius=5,
        color="green" if r.Class==1 else "red",fill=True,
        popup=f"Flight {r.FlightNumber} | {r.LaunchSite} | {'Success' if r.Class else 'Failure'}").add_to(cluster)
m.save("../figures/folium_launch_map.html")
m

# %% [markdown]
# Interactive HTML output: `figures/folium_launch_map.html`. Green/red markers represent successful/unsuccessful outcomes.
